# %%
import gymnasium as gym
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
from torch.distributions import MultivariateNormal
import imageio
from dmc import make_dmc_env
# Out:
# c:\Users\User\anaconda3\envs\DRL\lib\site-packages\gym\envs\registration.py:727: DeprecationWarning: The package name gym_minigrid has been deprecated in favor of minigrid. Please uninstall gym_minigrid and install minigrid with `pip install minigrid`. Future releases will be maintained under the new package name minigrid.
#   fn()
# c:\Users\User\anaconda3\envs\DRL\lib\site-packages\pygame\pkgdata.py:25: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import resource_stream, resource_exists

# %%
num_timesteps = 200 
num_trajectories = 10 
num_iterations = 250
epochs = 100

learning_rate = 3e-4
eps = 0.2 # clipping

# %%
env_name = "cartpole-balance"
env = make_dmc_env(env_name, np.random.randint(0, 1000000), flatten=True, use_pixels=False)
input_dim = env.observation_space.shape[0]
output_dim = env.action_space.shape[0]

# %%
print(input_dim, output_dim)
# Out:
# 5 1

# %%
class ReplayBuffer():
    def __init__(self):
        self.states = []
        self.actions = []
        self.rewards = []
        self.advantages = []
        self.values = []
        self.log_probs = []

    def push(self, state, action, reward, advantage, value, log_prob):
        self.states.append(state)
        self.actions.append(action)
        self.rewards.append(reward)
        self.advantages.append(advantage)
        self.values.append(value)  
        self.log_probs.append(log_prob)

    def sample(self):

        return (torch.tensor(self.states), 
                torch.tensor(self.actions), 
                torch.tensor(self.rewards),
                torch.tensor(self.advantages),
                torch.tensor(self.values),
                torch.tensor(self.log_probs))
    
    def clear(self):
        self.states = []
        self.actions = []
        self.rewards = []
        self.advantages = []
        self.values = []
        self.log_probs = []

# %%
class ValueNet(nn.Module):
    def __init__(self, input_size, output_size, hidden_size=64):
        super(ValueNet, self).__init__()
        self.seq = nn.Sequential(
            nn.Linear(input_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, output_size)
        )
    def forward(self, x):
        return self.seq(x)
class PolicyNet(nn.Module):
    def __init__(self, input_size, output_size, hidden_size=64):
        super(PolicyNet, self).__init__()
        self.seq = nn.Sequential(
            nn.Linear(input_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, hidden_size),
            nn.ReLU(),
        )
        self.mu = nn.Linear(hidden_size, output_size)

        # Global log_std as a learnable parameter (not state-dependent)
        self.log_std = nn.Parameter(torch.zeros(output_size))

    def forward(self, x):
        x = self.seq(x)
        mu = torch.tanh(self.mu(x))  # If env expects bounded actions like [-1, 1]
        std = torch.exp(self.log_std)  # Broadcasts over batch
        return mu, std
class PPO_agent:
    def __init__(self, input_dim, action_dim, gamma=0.99, learning_rate = 3e-4):

        self.policy_net = PolicyNet(input_dim, action_dim)
        self.critic_net = ValueNet(input_dim,1)
        self.optimizer = torch.optim.Adam([  # Update both models together
            {'params': self.policy_net.parameters(), 'lr': learning_rate},
            {'params': self.critic_net.parameters(), 'lr': learning_rate}
                    ])

        self.memory = ReplayBuffer()
        self.gamma = gamma
        self.lambda_ = 1
        self.vf_coef = 0.5 # c1
        self.entropy_coef = 0.01  # c2
        # use fixed std
        #self.std = torch.diag(torch.full(size=(1,)))
        self.eps = 0.2
    def get_advantages(self,rewards, values, gamma=0.99, lambda_=1):
        advantages = torch.zeros_like(torch.as_tensor(rewards))
        sum = 0
        for t in reversed(range(len(rewards)-1)):
            delta = rewards[t] + gamma * values[t + 1] - values[t]
            sum = delta + gamma * lambda_ * sum
            advantages[t] = sum
        return advantages
    def generate_trajectory(self):
        current_state, info = env.reset(seed=np.random.randint(0, 1000000))
        states = []
        actions = []
        rewards = []
        log_probs = []
                  
        for t in range(num_timesteps):
            with torch.no_grad():
                mean, std = self.policy_net(torch.as_tensor(np.array(current_state, dtype=np.float32)))
                normal = MultivariateNormal(mean, torch.diag_embed(std))
                action = normal.sample().detach()
                log_prob = normal.log_prob(action).detach()

            next_state, reward, terminated, truncated, info = env.step(action)

            states.append(np.array(current_state, dtype=np.float32))
            actions.append(action)
            rewards.append(reward)
            log_probs.append(log_prob)
        
            current_state = next_state
        
        # calculate values
        values = self.critic_net(torch.as_tensor(np.array(states, dtype=np.float32))).squeeze()
        # calculate advantages
        advantages = self.get_advantages(rewards, values.detach(), self.gamma, self.lambda_)
        # save the transitions in replay memory
        for t in range(len(advantages)):
            self.memory.push(states[t], actions[t], rewards[t], advantages[t], values[t], log_probs[t])
    def train(self):
        
        for iter_num in range(num_iterations): # k

            # collect a number of trajectories and save the transitions in replay memory
            for _ in range(num_trajectories):
                self.generate_trajectory()

            # sample from replay memory
            states, actions, rewards, advantages, values, log_probs = self.memory.sample()
            print("mean_advantages: ", torch.mean(advantages), end = ' | ')
            print("mean_values: ", torch.mean(values), end = ' | ')
            print("mean_reward: ", torch.mean(rewards))

            actor_losses = []
            critic_losses = []
            total_losses = []
            #reward_list = []
            for e in range(epochs):

                # calculate the new log prob
                mean, std = self.policy_net(states)
                normal = MultivariateNormal(mean, torch.diag_embed(std))
                new_log_probs = normal.log_prob(actions.unsqueeze(-1))

                r = torch.exp(new_log_probs - log_probs)

                clipped_r = torch.clamp(r, 1 - self.eps, 1 + self.eps)

                new_values = self.critic_net(states).squeeze()
                returns = (advantages + values).detach()

                actor_loss = (-torch.min(r * advantages, clipped_r * advantages)).mean()
                critic_loss = nn.MSELoss()(new_values.float(), returns.float())

                # Calcualte total loss
                total_loss = actor_loss + (self.vf_coef * critic_loss) - (self.entropy_coef * normal.entropy().mean())

                # update policy and critic network
                self.optimizer.zero_grad()
                total_loss.backward(retain_graph=True)
                self.optimizer.step()

                actor_losses.append(actor_loss.item())
                critic_losses.append(critic_loss.item())
                total_losses.append(total_loss.item())
                #reward_list.append(sum(rewards))

            # clear replay memory
            self.memory.clear()



            print("iteration = ",iter_num, end= ' : ')
            print('Actor loss = ', np.mean(actor_losses), end= ' | ')
            print('Critic loss = ', np.mean(critic_losses), end= ' | ')
            print('Total Loss = ', np.mean(total_losses), end= ' | ')
            print("")
    def saved(self):
        torch.save(self.policy_net.state_dict(), f'policy_net.pt')
        torch.save(self.critic_net.state_dict(), f'critic_net.pt')
    
    def load(self):
        self.policy_net.load_state_dict(torch.load(f'policy_net.pt'))
        self.critic_net.load_state_dict(torch.load(f'critic_net.pt'))
    def get_action(self, state):
        with torch.no_grad():
            mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
            normal = MultivariateNormal(mean, torch.diag_embed(std))
            action = normal.sample().detach().numpy()
            return action

    def test(self, load = False, vedio = False):
        if load:
            self.policy_net.load_state_dict(torch.load(f'policy_net.pt'))
        current_state, info = env.reset(seed=np.random.randint(0, 1000000))
        total_reward = 0
        frames = []
        while True:
            action = self.get_action(current_state)
            next_state, reward, terminated, truncated, info = env.step(action)
            if terminated or truncated:
                break
            total_reward += reward
            frame = env.render()
            frames.append(frame)
            current_state = next_state

        print(total_reward)
        imageio.mimsave("demo.gif", frames, fps=30)
        env.close()

# %%
agent = PPO_agent(input_dim=input_dim, action_dim=output_dim)

# %%
agent.train()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\230502442.py:53: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\torch\csrc\utils\tensor_new.cpp:257.)
#   return (torch.tensor(self.states),
# mean_advantages:  tensor(25.2029, dtype=torch.float64) | mean_values:  tensor(0.0228) | mean_reward:  tensor(0.5264, dtype=torch.float64)
# iteration =  0 : Actor loss =  -25.35712504434895 | Critic loss =  778.6397033691406 | Total Loss =  363.9485721302636 |
# mean_advantages:  tensor(28.9624, dtype=torch.float64) | mean_values:  tensor(3.4325) | mean_reward:  tensor(0.6140, dtype=torch.float64)
# iteration =  1 : Actor loss =  -29.303097540348578 | Critic loss =  1108.2313745117187 | Total Loss =  524.7986112659577 |
# mean_advantages:  tensor(25.6983, dtype=torch.float64) | mean_values:  tensor(11.5791) | mean_reward:  tensor(0.6268, dtype=torch.float64)
# iteration =  2 : Actor loss =  -25.91270789610055 | Critic loss =  937.0626831054688 | Total Loss =  442.6048540147132 |
# mean_advantages:  tensor(22.5925, dtype=torch.float64) | mean_values:  tensor(21.5566) | mean_reward:  tensor(0.6680, dtype=torch.float64)
# iteration =  3 : Actor loss =  -22.803521716260306 | Critic loss =  698.8003689575195 | Total Loss =  326.5830195878809 |
# mean_advantages:  tensor(11.7910, dtype=torch.float64) | mean_values:  tensor(35.4244) | mean_reward:  tensor(0.6389, dtype=torch.float64)
# iteration =  4 : Actor loss =  -11.87000307359192 | Critic loss =  247.43739334106445 | Total Loss =  111.83511565398034 |
# mean_advantages:  tensor(7.3553, dtype=torch.float64) | mean_values:  tensor(44.6685) | mean_reward:  tensor(0.6659, dtype=torch.float64)
# iteration =  5 : Actor loss =  -7.41585945040688 | Critic loss =  147.4113857269287 | Total Loss =  66.27625419810646 |
# mean_advantages:  tensor(1.9779, dtype=torch.float64) | mean_values:  tensor(51.5284) | mean_reward:  tensor(0.7052, dtype=torch.float64)
# iteration =  6 : Actor loss =  -2.0449991571475534 | Critic loss =  112.6078995513916 | Total Loss =  54.245355009917105 |
# mean_advantages:  tensor(-2.0554, dtype=torch.float64) | mean_values:  tensor(53.1344) | mean_reward:  tensor(0.7335, dtype=torch.float64)
# iteration =  7 : Actor loss =  1.997480019998869 | Critic loss =  81.23861701965332 | Total Loss =  42.60318389774965 |
# mean_advantages:  tensor(4.5681, dtype=torch.float64) | mean_values:  tensor(51.8163) | mean_reward:  tensor(0.7893, dtype=torch.float64)
# iteration =  8 : Actor loss =  -4.628740391431265 | Critic loss =  66.44094787597656 | Total Loss =  28.5781307939646 |
# mean_advantages:  tensor(0.9178, dtype=torch.float64) | mean_values:  tensor(60.1413) | mean_reward:  tensor(0.8319, dtype=torch.float64)
# iteration =  9 : Actor loss =  -0.960665732972749 | Critic loss =  38.885517044067385 | Total Loss =  18.468494453209956 |
# mean_advantages:  tensor(4.2404, dtype=torch.float64) | mean_values:  tensor(62.7418) | mean_reward:  tensor(0.8545, dtype=torch.float64)
# iteration =  10 : Actor loss =  -4.288249008610381 | Critic loss =  36.223158569335936 | Total Loss =  13.809745391885283 |
# mean_advantages:  tensor(3.8331, dtype=torch.float64) | mean_values:  tensor(71.5155) | mean_reward:  tensor(0.8767, dtype=torch.float64)
# iteration =  11 : Actor loss =  -3.852403634248917 | Critic loss =  8.36817777633667 | Total Loss =  0.31814334620473805 |
# mean_advantages:  tensor(3.8542, dtype=torch.float64) | mean_values:  tensor(77.7799) | mean_reward:  tensor(0.8835, dtype=torch.float64)
# iteration =  12 : Actor loss =  -3.869877510277433 | Critic loss =  8.111894278526306 | Total Loss =  0.17256040250708352 |
# mean_advantages:  tensor(2.0235, dtype=torch.float64) | mean_values:  tensor(80.9409) | mean_reward:  tensor(0.8845, dtype=torch.float64)
# iteration =  13 : Actor loss =  -2.031570044446555 | Critic loss =  2.8538446497917174 | Total Loss =  -0.6181283787710641 |
# mean_advantages:  tensor(0.3863, dtype=torch.float64) | mean_values:  tensor(89.4117) | mean_reward:  tensor(0.8899, dtype=torch.float64)
# iteration =  14 : Actor loss =  -0.3973138899282349 | Critic loss =  2.48479127407074 | Total Loss =  0.8316322727295773 |
# mean_advantages:  tensor(1.1107, dtype=torch.float64) | mean_values:  tensor(89.3093) | mean_reward:  tensor(0.8921, dtype=torch.float64)
# iteration =  15 : Actor loss =  -1.1235842015591349 | Critic loss =  2.2974147617816927 | Total Loss =  0.011695958590424453 |
# mean_advantages:  tensor(0.5117, dtype=torch.float64) | mean_values:  tensor(94.4228) | mean_reward:  tensor(0.8767, dtype=torch.float64)
# iteration =  16 : Actor loss =  -0.5199494699547544 | Critic loss =  1.045617289543152 | Total Loss =  -0.010546785180504748 |
# mean_advantages:  tensor(-1.6834, dtype=torch.float64) | mean_values:  tensor(101.3930) | mean_reward:  tensor(0.8276, dtype=torch.float64)
# iteration =  17 : Actor loss =  1.6644626438839174 | Critic loss =  11.306284208297729 | Total Loss =  7.304215101919863 |
# mean_advantages:  tensor(-2.9172, dtype=torch.float64) | mean_values:  tensor(98.8396) | mean_reward:  tensor(0.8342, dtype=torch.float64)
# iteration =  18 : Actor loss =  2.877705754482571 | Critic loss =  26.698069648742674 | Total Loss =  16.21336520258655 |
# mean_advantages:  tensor(-3.9924, dtype=torch.float64) | mean_values:  tensor(95.8941) | mean_reward:  tensor(0.8369, dtype=torch.float64)
# iteration =  19 : Actor loss =  3.959405323518934 | Critic loss =  12.03296919822693 | Total Loss =  9.962503414284932 |
# mean_advantages:  tensor(-0.2843, dtype=torch.float64) | mean_values:  tensor(90.0853) | mean_reward:  tensor(0.8804, dtype=torch.float64)
# iteration =  20 : Actor loss =  0.2819190272768816 | Critic loss =  1.342042772769928 | Total Loss =  0.9395245079869261 |
# mean_advantages:  tensor(-1.1235, dtype=torch.float64) | mean_values:  tensor(90.1343) | mean_reward:  tensor(0.8682, dtype=torch.float64)
# iteration =  21 : Actor loss =  1.1187388180618643 | Critic loss =  1.67017458319664 | Total Loss =  1.9404169171073944 |
# mean_advantages:  tensor(-0.1670, dtype=torch.float64) | mean_values:  tensor(88.7128) | mean_reward:  tensor(0.8875, dtype=torch.float64)
# iteration =  22 : Actor loss =  0.1649442362623662 | Critic loss =  1.1071843087673188 | Total Loss =  0.7051404188318551 |
# mean_advantages:  tensor(-0.9790, dtype=torch.float64) | mean_values:  tensor(88.0359) | mean_reward:  tensor(0.8720, dtype=torch.float64)
# iteration =  23 : Actor loss =  0.9738888169433588 | Critic loss =  1.9909277284145355 | Total Loss =  1.9559797741267493 |
# mean_advantages:  tensor(-0.0368, dtype=torch.float64) | mean_values:  tensor(87.3656) | mean_reward:  tensor(0.8796, dtype=torch.float64)
# iteration =  24 : Actor loss =  0.03287994154362453 | Critic loss =  0.9883866447210312 | Total Loss =  0.5137214585636414 |
# mean_advantages:  tensor(0.4862, dtype=torch.float64) | mean_values:  tensor(87.6201) | mean_reward:  tensor(0.8914, dtype=torch.float64)
# iteration =  25 : Actor loss =  -0.4881131391181871 | Critic loss =  0.6068714958429337 | Total Loss =  -0.19801030990213897 |
# mean_advantages:  tensor(0.1572, dtype=torch.float64) | mean_values:  tensor(88.3014) | mean_reward:  tensor(0.8922, dtype=torch.float64)
# iteration =  26 : Actor loss =  -0.15920220481299607 | Critic loss =  0.6470255613327026 | Total Loss =  0.15099876256591827 |
# mean_advantages:  tensor(-1.0225, dtype=torch.float64) | mean_values:  tensor(88.1012) | mean_reward:  tensor(0.8792, dtype=torch.float64)
# iteration =  27 : Actor loss =  1.0024382485865517 | Critic loss =  6.002817716598511 | Total Loss =  3.9905378681278694 |
# mean_advantages:  tensor(0.1468, dtype=torch.float64) | mean_values:  tensor(88.1652) | mean_reward:  tensor(0.8916, dtype=torch.float64)
# iteration =  28 : Actor loss =  -0.14992446623401545 | Critic loss =  0.874630628824234 | Total Loss =  0.2740674722973833 |
# mean_advantages:  tensor(-0.3036, dtype=torch.float64) | mean_values:  tensor(88.0964) | mean_reward:  tensor(0.8878, dtype=torch.float64)
# iteration =  29 : Actor loss =  0.2990926827535342 | Critic loss =  0.9710439372062684 | Total Loss =  0.7713012935638737 |
# mean_advantages:  tensor(-0.6301, dtype=torch.float64) | mean_values:  tensor(87.8047) | mean_reward:  tensor(0.8839, dtype=torch.float64)
# iteration =  30 : Actor loss =  0.6244553583537147 | Critic loss =  1.266120913028717 | Total Loss =  1.2442210514985874 |
# mean_advantages:  tensor(0.3336, dtype=torch.float64) | mean_values:  tensor(87.6317) | mean_reward:  tensor(0.8929, dtype=torch.float64)
# iteration =  31 : Actor loss =  -0.33742729709869473 | Critic loss =  0.7174536281824112 | Total Loss =  0.00804259214164469 |
# mean_advantages:  tensor(-0.8595, dtype=torch.float64) | mean_values:  tensor(88.0704) | mean_reward:  tensor(0.8802, dtype=torch.float64)
# iteration =  32 : Actor loss =  0.8505116025210652 | Critic loss =  2.2823735809326173 | Total Loss =  1.978488234760362 |
# mean_advantages:  tensor(-0.1673, dtype=torch.float64) | mean_values:  tensor(88.0156) | mean_reward:  tensor(0.8908, dtype=torch.float64)
# iteration =  33 : Actor loss =  0.16285450258164477 | Critic loss =  0.7805543369054795 | Total Loss =  0.5399695706261582 |
# mean_advantages:  tensor(0.2870, dtype=torch.float64) | mean_values:  tensor(88.7328) | mean_reward:  tensor(0.8948, dtype=torch.float64)
# iteration =  34 : Actor loss =  -0.28830454680606554 | Critic loss =  0.48145525217056273 | Total Loss =  -0.06068912311926312 |
# mean_advantages:  tensor(0.0323, dtype=torch.float64) | mean_values:  tensor(88.6384) | mean_reward:  tensor(0.8925, dtype=torch.float64)
# iteration =  35 : Actor loss =  -0.036360050636425716 | Critic loss =  1.0902898240089416 | Total Loss =  0.49569926643642775 |
# mean_advantages:  tensor(-0.0873, dtype=torch.float64) | mean_values:  tensor(88.6117) | mean_reward:  tensor(0.8894, dtype=torch.float64)
# iteration =  36 : Actor loss =  0.08224578851473492 | Critic loss =  0.8140956974029541 | Total Loss =  0.4762268511821793 |
# mean_advantages:  tensor(-0.2378, dtype=torch.float64) | mean_values:  tensor(88.7029) | mean_reward:  tensor(0.8910, dtype=torch.float64)
# iteration =  37 : Actor loss =  0.23418133041824823 | Critic loss =  0.5165916281938553 | Total Loss =  0.47944190467711223 |
# mean_advantages:  tensor(-0.1800, dtype=torch.float64) | mean_values:  tensor(88.7443) | mean_reward:  tensor(0.8904, dtype=torch.float64)
# iteration =  38 : Actor loss =  0.1780842535437902 | Critic loss =  0.5843298369646073 | Total Loss =  0.4572426677456012 |
# mean_advantages:  tensor(0.3856, dtype=torch.float64) | mean_values:  tensor(89.0745) | mean_reward:  tensor(0.8980, dtype=torch.float64)
# iteration =  39 : Actor loss =  -0.38663276509215655 | Critic loss =  0.376183218061924 | Total Loss =  -0.21151129253973788 |
# mean_advantages:  tensor(0.1042, dtype=torch.float64) | mean_values:  tensor(89.4483) | mean_reward:  tensor(0.8992, dtype=torch.float64)
# iteration =  40 : Actor loss =  -0.10622430218475215 | Critic loss =  0.2268256762623787 | Total Loss =  -0.005738340402937467 |
# mean_advantages:  tensor(-0.0157, dtype=torch.float64) | mean_values:  tensor(89.4588) | mean_reward:  tensor(0.8957, dtype=torch.float64)
# iteration =  41 : Actor loss =  0.014831582149435165 | Critic loss =  0.4315520602464676 | Total Loss =  0.21772368630388783 |
# mean_advantages:  tensor(-0.0059, dtype=torch.float64) | mean_values:  tensor(89.2679) | mean_reward:  tensor(0.8968, dtype=torch.float64)
# iteration =  42 : Actor loss =  0.0009795039706900542 | Critic loss =  0.44545836210250855 | Total Loss =  0.2108610362094864 |
# mean_advantages:  tensor(0.0768, dtype=torch.float64) | mean_values:  tensor(89.4689) | mean_reward:  tensor(0.8996, dtype=torch.float64)
# iteration =  43 : Actor loss =  -0.07912782198807966 | Critic loss =  0.3436401215195656 | Total Loss =  0.07987525143602121 |
# mean_advantages:  tensor(0.1618, dtype=torch.float64) | mean_values:  tensor(89.6244) | mean_reward:  tensor(0.8992, dtype=torch.float64)
# iteration =  44 : Actor loss =  -0.16318883392213962 | Critic loss =  0.3773373705148697 | Total Loss =  0.012708590112634676 |
# mean_advantages:  tensor(0.0917, dtype=torch.float64) | mean_values:  tensor(89.6982) | mean_reward:  tensor(0.8999, dtype=torch.float64)
# iteration =  45 : Actor loss =  -0.09306117730723514 | Critic loss =  0.30219517290592196 | Total Loss =  0.045310632795600166 |
# mean_advantages:  tensor(-0.1227, dtype=torch.float64) | mean_values:  tensor(89.9108) | mean_reward:  tensor(0.8999, dtype=torch.float64)
# iteration =  46 : Actor loss =  0.12167840227371388 | Critic loss =  0.3776801323890686 | Total Loss =  0.29783645679129594 |
# mean_advantages:  tensor(0.1839, dtype=torch.float64) | mean_values:  tensor(89.7068) | mean_reward:  tensor(0.9000, dtype=torch.float64)
# iteration =  47 : Actor loss =  -0.18627996713989764 | Critic loss =  0.45561461329460146 | Total Loss =  0.028895748172464087 |
# mean_advantages:  tensor(-0.1057, dtype=torch.float64) | mean_values:  tensor(89.8920) | mean_reward:  tensor(0.8975, dtype=torch.float64)
# iteration =  48 : Actor loss =  0.10366018596842029 | Critic loss =  0.24424906685948372 | Total Loss =  0.21321498259707428 |
# mean_advantages:  tensor(0.3617, dtype=torch.float64) | mean_values:  tensor(89.7270) | mean_reward:  tensor(0.9042, dtype=torch.float64)
# iteration =  49 : Actor loss =  -0.3636461102454923 | Critic loss =  0.2965849748253822 | Total Loss =  -0.22785590975126266 |
# mean_advantages:  tensor(0.1647, dtype=torch.float64) | mean_values:  tensor(90.1043) | mean_reward:  tensor(0.9049, dtype=torch.float64)
# iteration =  50 : Actor loss =  -0.1664915951741615 | Critic loss =  0.3101823982596397 | Total Loss =  -0.02382457028420064 |
# mean_advantages:  tensor(-0.2182, dtype=torch.float64) | mean_values:  tensor(90.3348) | mean_reward:  tensor(0.9013, dtype=torch.float64)
# iteration =  51 : Actor loss =  0.21641004747332093 | Critic loss =  0.27992180824279783 | Total Loss =  0.3440101330596304 |
# mean_advantages:  tensor(-0.0667, dtype=torch.float64) | mean_values:  tensor(90.3594) | mean_reward:  tensor(0.9035, dtype=torch.float64)
# iteration =  52 : Actor loss =  0.06470627078533031 | Critic loss =  0.24801527261734008 | Total Loss =  0.17641390355981745 |
# mean_advantages:  tensor(0.0175, dtype=torch.float64) | mean_values:  tensor(90.1471) | mean_reward:  tensor(0.9020, dtype=torch.float64)
# iteration =  53 : Actor loss =  -0.020216274367680576 | Critic loss =  0.3000189810991287 | Total Loss =  0.11757181254770814 |
# mean_advantages:  tensor(-0.1440, dtype=torch.float64) | mean_values:  tensor(90.2613) | mean_reward:  tensor(0.8997, dtype=torch.float64)
# iteration =  54 : Actor loss =  0.1415037251534293 | Critic loss =  0.3655515882372856 | Total Loss =  0.3121358632101099 |
# mean_advantages:  tensor(0.1791, dtype=torch.float64) | mean_values:  tensor(90.0417) | mean_reward:  tensor(0.9059, dtype=torch.float64)
# iteration =  55 : Actor loss =  -0.1857868725430341 | Critic loss =  0.419439769089222 | Total Loss =  0.011879762616368974 |
# mean_advantages:  tensor(-0.1062, dtype=torch.float64) | mean_values:  tensor(90.6614) | mean_reward:  tensor(0.9061, dtype=torch.float64)
# iteration =  56 : Actor loss =  0.10502339457842642 | Critic loss =  0.18008135348558427 | Total Loss =  0.18310118730860886 |
# mean_advantages:  tensor(-0.1647, dtype=torch.float64) | mean_values:  tensor(90.6001) | mean_reward:  tensor(0.9048, dtype=torch.float64)
# iteration =  57 : Actor loss =  0.16260475153286133 | Critic loss =  0.2251837457716465 | Total Loss =  0.2633044550958661 |
# mean_advantages:  tensor(-0.0366, dtype=torch.float64) | mean_values:  tensor(90.4859) | mean_reward:  tensor(0.9068, dtype=torch.float64)
# iteration =  58 : Actor loss =  0.03496309487045 | Critic loss =  0.2576002334058285 | Total Loss =  0.15193992765516232 |
# mean_advantages:  tensor(0.2473, dtype=torch.float64) | mean_values:  tensor(90.2457) | mean_reward:  tensor(0.9066, dtype=torch.float64)
# iteration =  59 : Actor loss =  -0.24942218384208378 | Critic loss =  0.24564791113138199 | Total Loss =  -0.13834034563476436 |
# mean_advantages:  tensor(0.1450, dtype=torch.float64) | mean_values:  tensor(90.5288) | mean_reward:  tensor(0.9092, dtype=torch.float64)
# iteration =  60 : Actor loss =  -0.1478075347396591 | Critic loss =  0.25048706129193304 | Total Loss =  -0.03421216670638408 |
# mean_advantages:  tensor(0.1150, dtype=torch.float64) | mean_values:  tensor(90.6294) | mean_reward:  tensor(0.9106, dtype=torch.float64)
# iteration =  61 : Actor loss =  -0.11731395868900092 | Critic loss =  0.14824469342827798 | Total Loss =  -0.0547435567466435 |
# mean_advantages:  tensor(-0.0464, dtype=torch.float64) | mean_values:  tensor(90.7636) | mean_reward:  tensor(0.9098, dtype=torch.float64)
# iteration =  62 : Actor loss =  0.04493175682452187 | Critic loss =  0.17530393093824387 | Total Loss =  0.12111681290742621 |
# mean_advantages:  tensor(-0.1263, dtype=torch.float64) | mean_values:  tensor(90.6006) | mean_reward:  tensor(0.9082, dtype=torch.float64)
# iteration =  63 : Actor loss =  0.122578507062094 | Critic loss =  0.2713411536812782 | Total Loss =  0.2468753922228233 |
# mean_advantages:  tensor(0.4304, dtype=torch.float64) | mean_values:  tensor(90.5604) | mean_reward:  tensor(0.9126, dtype=torch.float64)
# iteration =  64 : Actor loss =  -0.43311509908416823 | Critic loss =  0.28277419045567515 | Total Loss =  -0.3029861334921563 |
# mean_advantages:  tensor(0.1298, dtype=torch.float64) | mean_values:  tensor(90.9897) | mean_reward:  tensor(0.9128, dtype=torch.float64)
# iteration =  65 : Actor loss =  -0.1310568341759175 | Critic loss =  0.26998817652463913 | Total Loss =  -0.0071928561532080045 |
# mean_advantages:  tensor(0.2080, dtype=torch.float64) | mean_values:  tensor(91.1117) | mean_reward:  tensor(0.9161, dtype=torch.float64)
# iteration =  66 : Actor loss =  -0.20931115266897327 | Critic loss =  0.2234139433503151 | Total Loss =  -0.10862882019050961 |
# mean_advantages:  tensor(-0.0236, dtype=torch.float64) | mean_values:  tensor(91.4011) | mean_reward:  tensor(0.9147, dtype=torch.float64)
# iteration =  67 : Actor loss =  0.022435015505776826 | Critic loss =  0.16187679827213286 | Total Loss =  0.09244781114220721 |
# mean_advantages:  tensor(0.2820, dtype=torch.float64) | mean_values:  tensor(91.3336) | mean_reward:  tensor(0.9203, dtype=torch.float64)
# iteration =  68 : Actor loss =  -0.2837710189210418 | Critic loss =  0.21370928898453712 | Total Loss =  -0.18773893802856834 |
# mean_advantages:  tensor(0.0592, dtype=torch.float64) | mean_values:  tensor(91.4257) | mean_reward:  tensor(0.9178, dtype=torch.float64)
# iteration =  69 : Actor loss =  -0.06039125324927849 | Critic loss =  0.17361756831407546 | Total Loss =  0.01570725340626555 |
# mean_advantages:  tensor(-0.0350, dtype=torch.float64) | mean_values:  tensor(91.5816) | mean_reward:  tensor(0.9163, dtype=torch.float64)
# iteration =  70 : Actor loss =  0.03250990919973911 | Critic loss =  0.22443432956933976 | Total Loss =  0.1341092940719819 |
# mean_advantages:  tensor(0.0220, dtype=torch.float64) | mean_values:  tensor(91.8162) | mean_reward:  tensor(0.9190, dtype=torch.float64)
# iteration =  71 : Actor loss =  -0.023513872861713702 | Critic loss =  0.16385139569640159 | Total Loss =  0.04788020664282091 |
# mean_advantages:  tensor(0.1753, dtype=torch.float64) | mean_values:  tensor(91.8094) | mean_reward:  tensor(0.9212, dtype=torch.float64)
# iteration =  72 : Actor loss =  -0.17832864126732287 | Critic loss =  0.22177273660898209 | Total Loss =  -0.07788037454319835 |
# mean_advantages:  tensor(0.0310, dtype=torch.float64) | mean_values:  tensor(92.0653) | mean_reward:  tensor(0.9211, dtype=torch.float64)
# iteration =  73 : Actor loss =  -0.03382743216414782 | Critic loss =  0.29179733783006667 | Total Loss =  0.10176201332065432 |
# mean_advantages:  tensor(0.2326, dtype=torch.float64) | mean_values:  tensor(92.1468) | mean_reward:  tensor(0.9255, dtype=torch.float64)
# iteration =  74 : Actor loss =  -0.2341994157998889 | Critic loss =  0.14920542195439337 | Total Loss =  -0.16976325686155552 |
# mean_advantages:  tensor(0.0270, dtype=torch.float64) | mean_values:  tensor(92.3608) | mean_reward:  tensor(0.9244, dtype=torch.float64)
# iteration =  75 : Actor loss =  -0.029766445275116783 | Critic loss =  0.2761029481887817 | Total Loss =  0.0982631916332058 |
# mean_advantages:  tensor(-0.1247, dtype=torch.float64) | mean_values:  tensor(92.2533) | mean_reward:  tensor(0.9205, dtype=torch.float64)
# iteration =  76 : Actor loss =  0.12247273819723166 | Critic loss =  0.18191790744662284 | Total Loss =  0.2035416126085166 |
# mean_advantages:  tensor(0.1673, dtype=torch.float64) | mean_values:  tensor(92.2423) | mean_reward:  tensor(0.9252, dtype=torch.float64)
# iteration =  77 : Actor loss =  -0.16966602932856628 | Critic loss =  0.17656189024448396 | Total Loss =  -0.09116617106096095 |
# mean_advantages:  tensor(0.2919, dtype=torch.float64) | mean_values:  tensor(92.3838) | mean_reward:  tensor(0.9304, dtype=torch.float64)
# iteration =  78 : Actor loss =  -0.29465017417703787 | Critic loss =  0.1516955529153347 | Total Loss =  -0.22844308214520137 |
# mean_advantages:  tensor(-0.1045, dtype=torch.float64) | mean_values:  tensor(92.6775) | mean_reward:  tensor(0.9261, dtype=torch.float64)
# iteration =  79 : Actor loss =  0.10193050354994272 | Critic loss =  0.20378862902522088 | Total Loss =  0.19432231519646379 |
# mean_advantages:  tensor(0.2786, dtype=torch.float64) | mean_values:  tensor(92.5148) | mean_reward:  tensor(0.9308, dtype=torch.float64)
# iteration =  80 : Actor loss =  -0.2828880038197254 | Critic loss =  0.2228828601539135 | Total Loss =  -0.18080753140068698 |
# mean_advantages:  tensor(-0.0938, dtype=torch.float64) | mean_values:  tensor(92.9399) | mean_reward:  tensor(0.9299, dtype=torch.float64)
# iteration =  81 : Actor loss =  0.09118940207114512 | Critic loss =  0.18685585886240005 | Total Loss =  0.17540582456564605 |
# mean_advantages:  tensor(0.1010, dtype=torch.float64) | mean_values:  tensor(92.8084) | mean_reward:  tensor(0.9315, dtype=torch.float64)
# iteration =  82 : Actor loss =  -0.10213357389425479 | Critic loss =  0.07567232459783554 | Total Loss =  -0.07341967416448138 |
# mean_advantages:  tensor(-0.3841, dtype=torch.float64) | mean_values:  tensor(92.7339) | mean_reward:  tensor(0.9274, dtype=torch.float64)
# iteration =  83 : Actor loss =  0.3806925884303414 | Critic loss =  0.2685572221875191 | Total Loss =  0.5059422847111487 |
# mean_advantages:  tensor(0.1224, dtype=torch.float64) | mean_values:  tensor(92.5937) | mean_reward:  tensor(0.9324, dtype=torch.float64)
# iteration =  84 : Actor loss =  -0.12437002215847298 | Critic loss =  0.12972582191228865 | Total Loss =  -0.06842854189068003 |
# mean_advantages:  tensor(-0.0869, dtype=torch.float64) | mean_values:  tensor(92.3721) | mean_reward:  tensor(0.9316, dtype=torch.float64)
# iteration =  85 : Actor loss =  0.07923722996654643 | Critic loss =  0.5718201342225074 | Total Loss =  0.35636290133277604 |
# mean_advantages:  tensor(0.4679, dtype=torch.float64) | mean_values:  tensor(92.7154) | mean_reward:  tensor(0.9384, dtype=torch.float64)
# iteration =  86 : Actor loss =  -0.4721776502048771 | Critic loss =  0.2786855848133564 | Total Loss =  -0.34145694035386553 |
# mean_advantages:  tensor(0.2725, dtype=torch.float64) | mean_values:  tensor(93.3450) | mean_reward:  tensor(0.9387, dtype=torch.float64)
# iteration =  87 : Actor loss =  -0.2751288405724327 | Critic loss =  0.22974063143134116 | Total Loss =  -0.16869087811675768 |
# mean_advantages:  tensor(0.0725, dtype=torch.float64) | mean_values:  tensor(93.5018) | mean_reward:  tensor(0.9373, dtype=torch.float64)
# iteration =  88 : Actor loss =  -0.07487365664083316 | Critic loss =  0.1450752118229866 | Total Loss =  -0.010611459446212198 |
# mean_advantages:  tensor(0.1507, dtype=torch.float64) | mean_values:  tensor(93.7062) | mean_reward:  tensor(0.9411, dtype=torch.float64)
# iteration =  89 : Actor loss =  -0.153059209468479 | Critic loss =  0.16315213963389397 | Total Loss =  -0.0796132861214529 |
# mean_advantages:  tensor(0.0800, dtype=torch.float64) | mean_values:  tensor(93.7650) | mean_reward:  tensor(0.9414, dtype=torch.float64)
# iteration =  90 : Actor loss =  -0.08390527702491642 | Critic loss =  0.25382230535149575 | Total Loss =  0.03504935929928062 |
# mean_advantages:  tensor(0.0615, dtype=torch.float64) | mean_values:  tensor(93.9435) | mean_reward:  tensor(0.9425, dtype=torch.float64)
# iteration =  91 : Actor loss =  -0.06506251279376443 | Critic loss =  0.1992120026051998 | Total Loss =  0.02675476133711641 |
# mean_advantages:  tensor(0.0489, dtype=torch.float64) | mean_values:  tensor(94.0813) | mean_reward:  tensor(0.9432, dtype=torch.float64)
# iteration =  92 : Actor loss =  -0.05077605823150741 | Critic loss =  0.17629206895828248 | Total Loss =  0.029717035585987407 |
# mean_advantages:  tensor(-0.0258, dtype=torch.float64) | mean_values:  tensor(94.2240) | mean_reward:  tensor(0.9427, dtype=torch.float64)
# iteration =  93 : Actor loss =  0.024067493898143402 | Critic loss =  0.19276346802711486 | Total Loss =  0.11292081378614656 |
# mean_advantages:  tensor(0.2086, dtype=torch.float64) | mean_values:  tensor(94.1266) | mean_reward:  tensor(0.9452, dtype=torch.float64)
# iteration =  94 : Actor loss =  -0.21191042009385952 | Critic loss =  0.17764381676912308 | Total Loss =  -0.13046276601607626 |
# mean_advantages:  tensor(0.1426, dtype=torch.float64) | mean_values:  tensor(94.3761) | mean_reward:  tensor(0.9461, dtype=torch.float64)
# iteration =  95 : Actor loss =  -0.1445094208635948 | Critic loss =  0.11330345034599304 | Total Loss =  -0.09508855118719856 |
# mean_advantages:  tensor(0.2820, dtype=torch.float64) | mean_values:  tensor(94.5341) | mean_reward:  tensor(0.9504, dtype=torch.float64)
# iteration =  96 : Actor loss =  -0.28370116525012223 | Critic loss =  0.08555433250963689 | Total Loss =  -0.24803180555029924 |
# mean_advantages:  tensor(0.0248, dtype=torch.float64) | mean_values:  tensor(94.8322) | mean_reward:  tensor(0.9487, dtype=torch.float64)
# iteration =  97 : Actor loss =  -0.026795345592551506 | Critic loss =  0.1567696999013424 | Total Loss =  0.04461310807964149 |
# mean_advantages:  tensor(-0.0709, dtype=torch.float64) | mean_values:  tensor(94.7824) | mean_reward:  tensor(0.9488, dtype=torch.float64)
# iteration =  98 : Actor loss =  0.06759387389065012 | Critic loss =  0.2136719247698784 | Total Loss =  0.16758634759818453 |
# mean_advantages:  tensor(0.3163, dtype=torch.float64) | mean_values:  tensor(94.5254) | mean_reward:  tensor(0.9517, dtype=torch.float64)
# iteration =  99 : Actor loss =  -0.320270439474045 | Critic loss =  0.12804069519042968 | Total Loss =  -0.26295135887259863 |
# mean_advantages:  tensor(0.0520, dtype=torch.float64) | mean_values:  tensor(95.0687) | mean_reward:  tensor(0.9525, dtype=torch.float64)
# iteration =  100 : Actor loss =  -0.053679717687302106 | Critic loss =  0.09146403260529042 | Total Loss =  -0.014505109317944234 |
# mean_advantages:  tensor(-0.0903, dtype=torch.float64) | mean_values:  tensor(95.0402) | mean_reward:  tensor(0.9505, dtype=torch.float64)
# iteration =  101 : Actor loss =  0.08861202985870693 | Critic loss =  0.10177670732140541 | Total Loss =  0.13304348599988078 |
# mean_advantages:  tensor(0.0471, dtype=torch.float64) | mean_values:  tensor(94.9784) | mean_reward:  tensor(0.9529, dtype=torch.float64)
# iteration =  102 : Actor loss =  -0.05179220419208623 | Critic loss =  0.20323327258229257 | Total Loss =  0.04346915192139231 |
# mean_advantages:  tensor(0.2741, dtype=torch.float64) | mean_values:  tensor(95.1447) | mean_reward:  tensor(0.9557, dtype=torch.float64)
# iteration =  103 : Actor loss =  -0.27571865735495443 | Critic loss =  0.08842972248792648 | Total Loss =  -0.23774704283488896 |
# mean_advantages:  tensor(-0.2426, dtype=torch.float64) | mean_values:  tensor(95.2302) | mean_reward:  tensor(0.9553, dtype=torch.float64)
# iteration =  104 : Actor loss =  0.2361994453405762 | Critic loss =  0.41808694034814836 | Total Loss =  0.4391179720571065 |
# mean_advantages:  tensor(0.1060, dtype=torch.float64) | mean_values:  tensor(95.5378) | mean_reward:  tensor(0.9576, dtype=torch.float64)
# iteration =  105 : Actor loss =  -0.10750426629445861 | Critic loss =  0.0908814649283886 | Total Loss =  -0.06807638134695003 |
# mean_advantages:  tensor(0.0770, dtype=torch.float64) | mean_values:  tensor(95.6586) | mean_reward:  tensor(0.9583, dtype=torch.float64)
# iteration =  106 : Actor loss =  -0.07856328399370843 | Critic loss =  0.12383167907595634 | Total Loss =  -0.02254728331215167 |
# mean_advantages:  tensor(0.0446, dtype=torch.float64) | mean_values:  tensor(95.6948) | mean_reward:  tensor(0.9577, dtype=torch.float64)
# iteration =  107 : Actor loss =  -0.046402778236040325 | Critic loss =  0.09815099664032459 | Total Loss =  -0.0031006448081074517 |
# mean_advantages:  tensor(-0.0652, dtype=torch.float64) | mean_values:  tensor(95.5478) | mean_reward:  tensor(0.9589, dtype=torch.float64)
# iteration =  108 : Actor loss =  0.06224851679344684 | Critic loss =  0.0952581250667572 | Total Loss =  0.10420423397616506 |
# mean_advantages:  tensor(-0.0037, dtype=torch.float64) | mean_values:  tensor(95.6858) | mean_reward:  tensor(0.9566, dtype=torch.float64)
# iteration =  109 : Actor loss =  0.0018140574635091655 | Critic loss =  0.1127403961122036 | Total Loss =  0.05259708927917215 |
# mean_advantages:  tensor(0.1953, dtype=torch.float64) | mean_values:  tensor(95.7121) | mean_reward:  tensor(0.9601, dtype=torch.float64)
# iteration =  110 : Actor loss =  -0.19872697946533824 | Critic loss =  0.10804033897817135 | Total Loss =  -0.15014421619393195 |
# mean_advantages:  tensor(-0.0260, dtype=torch.float64) | mean_values:  tensor(95.9534) | mean_reward:  tensor(0.9594, dtype=torch.float64)
# iteration =  111 : Actor loss =  0.024542087996493683 | Critic loss =  0.08007320873439312 | Total Loss =  0.05929155330650847 |
# mean_advantages:  tensor(0.0609, dtype=torch.float64) | mean_values:  tensor(95.9699) | mean_reward:  tensor(0.9609, dtype=torch.float64)
# iteration =  112 : Actor loss =  -0.06214353578128429 | Critic loss =  0.09800695098936557 | Total Loss =  -0.01831626311839134 |
# mean_advantages:  tensor(0.0816, dtype=torch.float64) | mean_values:  tensor(95.9794) | mean_reward:  tensor(0.9621, dtype=torch.float64)
# iteration =  113 : Actor loss =  -0.08357296714787378 | Critic loss =  0.09741052277386189 | Total Loss =  -0.039902172328392126 |
# mean_advantages:  tensor(0.2367, dtype=torch.float64) | mean_values:  tensor(96.1157) | mean_reward:  tensor(0.9657, dtype=torch.float64)
# iteration =  114 : Actor loss =  -0.23811308333197886 | Critic loss =  0.09210325680673122 | Total Loss =  -0.1969369488024553 |
# mean_advantages:  tensor(0.0268, dtype=torch.float64) | mean_values:  tensor(96.3288) | mean_reward:  tensor(0.9648, dtype=torch.float64)
# iteration =  115 : Actor loss =  -0.02846688279353728 | Critic loss =  0.08837145663797856 | Total Loss =  0.010988811092146727 |
# mean_advantages:  tensor(0.1749, dtype=torch.float64) | mean_values:  tensor(96.3685) | mean_reward:  tensor(0.9665, dtype=torch.float64)
# iteration =  116 : Actor loss =  -0.17634924883015052 | Critic loss =  0.08010711841285229 | Total Loss =  -0.1408926018419821 |
# mean_advantages:  tensor(0.0084, dtype=torch.float64) | mean_values:  tensor(96.5022) | mean_reward:  tensor(0.9653, dtype=torch.float64)
# iteration =  117 : Actor loss =  -0.009311926950746728 | Critic loss =  0.04352950427681208 | Total Loss =  0.007984628170682538 |
# mean_advantages:  tensor(0.0538, dtype=torch.float64) | mean_values:  tensor(96.5253) | mean_reward:  tensor(0.9670, dtype=torch.float64)
# iteration =  118 : Actor loss =  -0.054756067963312595 | Critic loss =  0.06646440505981445 | Total Loss =  -0.025889478884632916 |
# mean_advantages:  tensor(0.1056, dtype=torch.float64) | mean_values:  tensor(96.5120) | mean_reward:  tensor(0.9682, dtype=torch.float64)
# iteration =  119 : Actor loss =  -0.10742802134923975 | Critic loss =  0.09109664134681225 | Total Loss =  -0.06612518368497829 |
# mean_advantages:  tensor(0.1055, dtype=torch.float64) | mean_values:  tensor(96.6568) | mean_reward:  tensor(0.9678, dtype=torch.float64)
# iteration =  120 : Actor loss =  -0.10675865753189213 | Critic loss =  0.04829019889235497 | Total Loss =  -0.08673782469805814 |
# mean_advantages:  tensor(-0.0220, dtype=torch.float64) | mean_values:  tensor(96.7835) | mean_reward:  tensor(0.9682, dtype=torch.float64)
# iteration =  121 : Actor loss =  0.02035558831497892 | Critic loss =  0.06140797540545464 | Total Loss =  0.04704763877291097 |
# mean_advantages:  tensor(0.1545, dtype=torch.float64) | mean_values:  tensor(96.7718) | mean_reward:  tensor(0.9703, dtype=torch.float64)
# iteration =  122 : Actor loss =  -0.15630044930145792 | Critic loss =  0.04391168646514416 | Total Loss =  -0.1382412419886952 |
# mean_advantages:  tensor(0.1481, dtype=torch.float64) | mean_values:  tensor(96.9083) | mean_reward:  tensor(0.9711, dtype=torch.float64)
# iteration =  123 : Actor loss =  -0.14950234000295798 | Critic loss =  0.04946900650858879 | Total Loss =  -0.12854227279736127 |
# mean_advantages:  tensor(0.0161, dtype=torch.float64) | mean_values:  tensor(97.0578) | mean_reward:  tensor(0.9707, dtype=torch.float64)
# iteration =  124 : Actor loss =  -0.017323402952680377 | Critic loss =  0.052327284701168535 | Total Loss =  0.005177097153572353 |
# mean_advantages:  tensor(0.0254, dtype=torch.float64) | mean_values:  tensor(97.0729) | mean_reward:  tensor(0.9722, dtype=torch.float64)
# iteration =  125 : Actor loss =  -0.026648760929713248 | Critic loss =  0.048512129671871664 | Total Loss =  -0.005944608729807882 |
# mean_advantages:  tensor(0.1163, dtype=torch.float64) | mean_values:  tensor(97.0867) | mean_reward:  tensor(0.9728, dtype=torch.float64)
# iteration =  126 : Actor loss =  -0.11755696508831734 | Critic loss =  0.05470497477799654 | Total Loss =  -0.09362844966615941 |
# mean_advantages:  tensor(-0.0860, dtype=torch.float64) | mean_values:  tensor(97.2061) | mean_reward:  tensor(0.9718, dtype=torch.float64)
# iteration =  127 : Actor loss =  0.08473531755002339 | Critic loss =  0.04876620501279831 | Total Loss =  0.10580325041514016 |
# mean_advantages:  tensor(0.1172, dtype=torch.float64) | mean_values:  tensor(97.1434) | mean_reward:  tensor(0.9733, dtype=torch.float64)
# iteration =  128 : Actor loss =  -0.11851188939349923 | Critic loss =  0.04946042027324438 | Total Loss =  -0.09698671273008187 |
# mean_advantages:  tensor(0.0226, dtype=torch.float64) | mean_values:  tensor(97.2477) | mean_reward:  tensor(0.9729, dtype=torch.float64)
# iteration =  129 : Actor loss =  -0.02389758826893185 | Critic loss =  0.03788548119366169 | Total Loss =  -0.008042904890220508 |
# mean_advantages:  tensor(0.0377, dtype=torch.float64) | mean_values:  tensor(97.2818) | mean_reward:  tensor(0.9736, dtype=torch.float64)
# iteration =  130 : Actor loss =  -0.03923624082199627 | Critic loss =  0.033937676958739754 | Total Loss =  -0.025265325675358562 |
# mean_advantages:  tensor(0.0648, dtype=torch.float64) | mean_values:  tensor(97.3712) | mean_reward:  tensor(0.9751, dtype=torch.float64)
# iteration =  131 : Actor loss =  -0.06611612362190222 | Critic loss =  0.0337266306206584 | Total Loss =  -0.05216681467703617 |
# mean_advantages:  tensor(0.0721, dtype=torch.float64) | mean_values:  tensor(97.4515) | mean_reward:  tensor(0.9755, dtype=torch.float64)
# iteration =  132 : Actor loss =  -0.07287100806524766 | Critic loss =  0.028546263705939056 | Total Loss =  -0.06142926853541073 |
# mean_advantages:  tensor(0.0149, dtype=torch.float64) | mean_values:  tensor(97.5101) | mean_reward:  tensor(0.9748, dtype=torch.float64)
# iteration =  133 : Actor loss =  -0.015973054406701867 | Critic loss =  0.03359810281544924 | Total Loss =  -0.0019064888414026201 |
# mean_advantages:  tensor(0.1086, dtype=torch.float64) | mean_values:  tensor(97.5521) | mean_reward:  tensor(0.9772, dtype=torch.float64)
# iteration =  134 : Actor loss =  -0.10957687973164881 | Critic loss =  0.03874576710164547 | Total Loss =  -0.09281910965339209 |
# mean_advantages:  tensor(0.0160, dtype=torch.float64) | mean_values:  tensor(97.6546) | mean_reward:  tensor(0.9763, dtype=torch.float64)
# iteration =  135 : Actor loss =  -0.017073389971185134 | Critic loss =  0.0332534421607852 | Total Loss =  -0.0029387614755180015 |
# mean_advantages:  tensor(-0.0096, dtype=torch.float64) | mean_values:  tensor(97.7155) | mean_reward:  tensor(0.9770, dtype=torch.float64)
# iteration =  136 : Actor loss =  0.00893792644478166 | Critic loss =  0.02797289703041315 | Total Loss =  0.020535287480892332 |
# mean_advantages:  tensor(0.1008, dtype=torch.float64) | mean_values:  tensor(97.7015) | mean_reward:  tensor(0.9788, dtype=torch.float64)
# iteration =  137 : Actor loss =  -0.10191206503014585 | Critic loss =  0.017651800941675903 | Total Loss =  -0.09538001130621454 |
# mean_advantages:  tensor(-0.0035, dtype=torch.float64) | mean_values:  tensor(97.8083) | mean_reward:  tensor(0.9772, dtype=torch.float64)
# iteration =  138 : Actor loss =  0.0026803860526548274 | Critic loss =  0.024202299676835536 | Total Loss =  0.012583005751205379 |
# mean_advantages:  tensor(0.0198, dtype=torch.float64) | mean_values:  tensor(97.8170) | mean_reward:  tensor(0.9785, dtype=torch.float64)
# iteration =  139 : Actor loss =  -0.021060013250658427 | Critic loss =  0.03935599651187658 | Total Loss =  -0.003465643326031182 |
# mean_advantages:  tensor(-0.0645, dtype=torch.float64) | mean_values:  tensor(97.8889) | mean_reward:  tensor(0.9779, dtype=torch.float64)
# iteration =  140 : Actor loss =  0.06360474826615929 | Critic loss =  0.019745486825704574 | Total Loss =  0.07152130022143638 |
# mean_advantages:  tensor(-0.0168, dtype=torch.float64) | mean_values:  tensor(97.8544) | mean_reward:  tensor(0.9788, dtype=torch.float64)
# iteration =  141 : Actor loss =  0.01535251850870195 | Critic loss =  0.03397713724523783 | Total Loss =  0.030481192101982777 |
# mean_advantages:  tensor(0.0803, dtype=torch.float64) | mean_values:  tensor(97.8668) | mean_reward:  tensor(0.9793, dtype=torch.float64)
# iteration =  142 : Actor loss =  -0.0811083652812997 | Critic loss =  0.026007805075496434 | Total Loss =  -0.06986663615801465 |
# mean_advantages:  tensor(-0.0233, dtype=torch.float64) | mean_values:  tensor(97.9602) | mean_reward:  tensor(0.9794, dtype=torch.float64)
# iteration =  143 : Actor loss =  0.02130615224690838 | Critic loss =  0.039183453656733036 | Total Loss =  0.03924554057048364 |
# mean_advantages:  tensor(-0.0147, dtype=torch.float64) | mean_values:  tensor(97.9987) | mean_reward:  tensor(0.9798, dtype=torch.float64)
# iteration =  144 : Actor loss =  0.013870381195461912 | Critic loss =  0.030619342420250176 | Total Loss =  0.027639726596549678 |
# mean_advantages:  tensor(0.0918, dtype=torch.float64) | mean_values:  tensor(97.9662) | mean_reward:  tensor(0.9812, dtype=torch.float64)
# iteration =  145 : Actor loss =  -0.09278010351103169 | Critic loss =  0.028647803124040364 | Total Loss =  -0.0798729377203565 |
# mean_advantages:  tensor(0.0520, dtype=torch.float64) | mean_values:  tensor(98.0301) | mean_reward:  tensor(0.9807, dtype=torch.float64)
# iteration =  146 : Actor loss =  -0.053072368558184105 | Critic loss =  0.02377898745238781 | Total Loss =  -0.04246539662444484 |
# mean_advantages:  tensor(0.0449, dtype=torch.float64) | mean_values:  tensor(98.1651) | mean_reward:  tensor(0.9821, dtype=torch.float64)
# iteration =  147 : Actor loss =  -0.04581929600840826 | Critic loss =  0.027421216052025556 | Total Loss =  -0.03326633878211884 |
# mean_advantages:  tensor(0.0708, dtype=torch.float64) | mean_values:  tensor(98.1437) | mean_reward:  tensor(0.9825, dtype=torch.float64)
# iteration =  148 : Actor loss =  -0.07132780010310746 | Critic loss =  0.012686504181474448 | Total Loss =  -0.06602962955564073 |
# mean_advantages:  tensor(-0.0010, dtype=torch.float64) | mean_values:  tensor(98.2212) | mean_reward:  tensor(0.9827, dtype=torch.float64)
# iteration =  149 : Actor loss =  -0.00033406965112673124 | Critic loss =  0.02028594296425581 | Total Loss =  0.008856510936474556 |
# mean_advantages:  tensor(0.0132, dtype=torch.float64) | mean_values:  tensor(98.1866) | mean_reward:  tensor(0.9824, dtype=torch.float64)
# iteration =  150 : Actor loss =  -0.014177389883115166 | Critic loss =  0.020155295338481663 | Total Loss =  -0.004959047721494197 |
# mean_advantages:  tensor(0.0002, dtype=torch.float64) | mean_values:  tensor(98.2861) | mean_reward:  tensor(0.9833, dtype=torch.float64)
# iteration =  151 : Actor loss =  -0.0009363687981820242 | Critic loss =  0.011360104363411665 | Total Loss =  0.003961035464264774 |
# mean_advantages:  tensor(0.0751, dtype=torch.float64) | mean_values:  tensor(98.2657) | mean_reward:  tensor(0.9840, dtype=torch.float64)
# iteration =  152 : Actor loss =  -0.07622243539751868 | Critic loss =  0.018156930720433593 | Total Loss =  -0.06784307860916375 |
# mean_advantages:  tensor(-0.0018, dtype=torch.float64) | mean_values:  tensor(98.3298) | mean_reward:  tensor(0.9833, dtype=torch.float64)
# iteration =  153 : Actor loss =  0.00128055444500604 | Critic loss =  0.00975221156142652 | Total Loss =  0.005537181616422807 |
# mean_advantages:  tensor(0.0306, dtype=torch.float64) | mean_values:  tensor(98.3707) | mean_reward:  tensor(0.9843, dtype=torch.float64)
# iteration =  154 : Actor loss =  -0.03114658879867778 | Critic loss =  0.00927264324389398 | Total Loss =  -0.027090532173700863 |
# mean_advantages:  tensor(0.0288, dtype=torch.float64) | mean_values:  tensor(98.4126) | mean_reward:  tensor(0.9847, dtype=torch.float64)
# iteration =  155 : Actor loss =  -0.029540801691453556 | Critic loss =  0.016669153533875943 | Total Loss =  -0.02170207405024313 |
# mean_advantages:  tensor(0.0342, dtype=torch.float64) | mean_values:  tensor(98.3792) | mean_reward:  tensor(0.9842, dtype=torch.float64)
# iteration =  156 : Actor loss =  -0.03496422194785237 | Critic loss =  0.020072040893137456 | Total Loss =  -0.025300871806943636 |
# mean_advantages:  tensor(-0.0317, dtype=torch.float64) | mean_values:  tensor(98.4202) | mean_reward:  tensor(0.9834, dtype=torch.float64)
# iteration =  157 : Actor loss =  0.030716814700059415 | Critic loss =  0.015573654500767588 | Total Loss =  0.03826813365878124 |
# mean_advantages:  tensor(0.0748, dtype=torch.float64) | mean_values:  tensor(98.4165) | mean_reward:  tensor(0.9850, dtype=torch.float64)
# iteration =  158 : Actor loss =  -0.07546357240886158 | Critic loss =  0.014511566385626793 | Total Loss =  -0.06831934141677215 |
# mean_advantages:  tensor(0.0586, dtype=torch.float64) | mean_values:  tensor(98.4907) | mean_reward:  tensor(0.9859, dtype=torch.float64)
# iteration =  159 : Actor loss =  -0.05932681311502587 | Critic loss =  0.012164805447682739 | Total Loss =  -0.05324784315378916 |
# mean_advantages:  tensor(-0.0053, dtype=torch.float64) | mean_values:  tensor(98.5376) | mean_reward:  tensor(0.9850, dtype=torch.float64)
# iteration =  160 : Actor loss =  0.004728569107324697 | Critic loss =  0.009891774049028754 | Total Loss =  0.009768982134415531 |
# mean_advantages:  tensor(0.0273, dtype=torch.float64) | mean_values:  tensor(98.5032) | mean_reward:  tensor(0.9850, dtype=torch.float64)
# iteration =  161 : Actor loss =  -0.028453995699936372 | Critic loss =  0.014840047182515264 | Total Loss =  -0.020851149062771898 |
# mean_advantages:  tensor(0.0325, dtype=torch.float64) | mean_values:  tensor(98.5616) | mean_reward:  tensor(0.9860, dtype=torch.float64)
# iteration =  162 : Actor loss =  -0.03318418576839088 | Critic loss =  0.01049554042518139 | Total Loss =  -0.02768312005841346 |
# mean_advantages:  tensor(0.0208, dtype=torch.float64) | mean_values:  tensor(98.5488) | mean_reward:  tensor(0.9863, dtype=torch.float64)
# iteration =  163 : Actor loss =  -0.021700237992886243 | Critic loss =  0.011211710954084993 | Total Loss =  -0.015785843144371887 |
# mean_advantages:  tensor(0.0448, dtype=torch.float64) | mean_values:  tensor(98.6366) | mean_reward:  tensor(0.9862, dtype=torch.float64)
# iteration =  164 : Actor loss =  -0.0455303184124803 | Critic loss =  0.01408200259320438 | Total Loss =  -0.038087677661520304 |
# mean_advantages:  tensor(-0.0263, dtype=torch.float64) | mean_values:  tensor(98.6943) | mean_reward:  tensor(0.9864, dtype=torch.float64)
# iteration =  165 : Actor loss =  0.02563864167410217 | Critic loss =  0.008931059837341309 | Total Loss =  0.030612912269514406 |
# mean_advantages:  tensor(-0.0231, dtype=torch.float64) | mean_values:  tensor(98.6801) | mean_reward:  tensor(0.9863, dtype=torch.float64)
# iteration =  166 : Actor loss =  0.02229712985207712 | Critic loss =  0.007184541691094637 | Total Loss =  0.026458949593206996 |
# mean_advantages:  tensor(0.0437, dtype=torch.float64) | mean_values:  tensor(98.6720) | mean_reward:  tensor(0.9868, dtype=torch.float64)
# iteration =  167 : Actor loss =  -0.044297384750229825 | Critic loss =  0.012095140358433128 | Total Loss =  -0.037583340519472534 |
# mean_advantages:  tensor(0.0325, dtype=torch.float64) | mean_values:  tensor(98.7131) | mean_reward:  tensor(0.9872, dtype=torch.float64)
# iteration =  168 : Actor loss =  -0.033211760187748116 | Critic loss =  0.0070793985016644 | Total Loss =  -0.028885189129848263 |
# mean_advantages:  tensor(0.0106, dtype=torch.float64) | mean_values:  tensor(98.7560) | mean_reward:  tensor(0.9873, dtype=torch.float64)
# iteration =  169 : Actor loss =  -0.011249098460979767 | Critic loss =  0.009273538775742053 | Total Loss =  -0.005737916335787634 |
# mean_advantages:  tensor(0.0037, dtype=torch.float64) | mean_values:  tensor(98.7896) | mean_reward:  tensor(0.9877, dtype=torch.float64)
# iteration =  170 : Actor loss =  -0.004186496898602808 | Critic loss =  0.009499886687844992 | Total Loss =  0.001561243964404684 |
# mean_advantages:  tensor(0.0791, dtype=torch.float64) | mean_values:  tensor(98.7769) | mean_reward:  tensor(0.9887, dtype=torch.float64)
# iteration =  171 : Actor loss =  -0.07981766881779638 | Critic loss =  0.006447241436690092 | Total Loss =  -0.07547411861722228 |
# mean_advantages:  tensor(-0.0064, dtype=torch.float64) | mean_values:  tensor(98.8326) | mean_reward:  tensor(0.9877, dtype=torch.float64)
# iteration =  172 : Actor loss =  0.005711837332591062 | Critic loss =  0.008607614906504751 | Total Loss =  0.01123635661870951 |
# mean_advantages:  tensor(-0.0244, dtype=torch.float64) | mean_values:  tensor(98.8419) | mean_reward:  tensor(0.9880, dtype=torch.float64)
# iteration =  173 : Actor loss =  0.023738396755458094 | Critic loss =  0.00784280756022781 | Total Loss =  0.028957935513268463 |
# mean_advantages:  tensor(0.0711, dtype=torch.float64) | mean_values:  tensor(98.8315) | mean_reward:  tensor(0.9887, dtype=torch.float64)
# iteration =  174 : Actor loss =  -0.07152850022286475 | Critic loss =  0.006168903741054237 | Total Loss =  -0.06704683891011701 |
# mean_advantages:  tensor(0.0165, dtype=torch.float64) | mean_values:  tensor(98.9274) | mean_reward:  tensor(0.9893, dtype=torch.float64)
# iteration =  175 : Actor loss =  -0.01700371239583147 | Critic loss =  0.005988806164823473 | Total Loss =  -0.012505584741170977 |
# mean_advantages:  tensor(0.0404, dtype=torch.float64) | mean_values:  tensor(98.9464) | mean_reward:  tensor(0.9898, dtype=torch.float64)
# iteration =  176 : Actor loss =  -0.041073411177298895 | Critic loss =  0.005332334423437715 | Total Loss =  -0.036814367485153404 |
# mean_advantages:  tensor(0.0068, dtype=torch.float64) | mean_values:  tensor(98.9815) | mean_reward:  tensor(0.9892, dtype=torch.float64)
# iteration =  177 : Actor loss =  -0.00743874565910256 | Critic loss =  0.007966749030165374 | Total Loss =  -0.0017493265213229373 |
# ...
# iteration =  191 : Actor loss =  -0.06993361833328543 | Critic loss =  0.005782703408040106 | Total Loss =  -0.06443879450727416 |
# mean_advantages:  tensor(-0.0103, dtype=torch.float64) | mean_values:  tensor(99.1744) | mean_reward:  tensor(0.9913, dtype=torch.float64)
# iteration =  192 : Actor loss =  0.009831412558728724 | Critic loss =  0.003709193349350244 | Total Loss =  0.014406432269193123 |
# mean_advantages:  tensor(0.0316, dtype=torch.float64) | mean_values:  tensor(99.1599) | mean_reward:  tensor(0.9919, dtype=torch.float64)
# iteration =  193 : Actor loss =  -0.031960163412641934 | Critic loss =  0.003835953678935766 | Total Loss =  -0.027304306906208595 |
# mean_advantages:  tensor(0.0074, dtype=torch.float64) | mean_values:  tensor(99.1588) | mean_reward:  tensor(0.9908, dtype=torch.float64)
# iteration =  194 : Actor loss =  -0.00803322296866228 | Critic loss =  0.004241716268006712 | Total Loss =  -0.003126938903443639 |
# mean_advantages:  tensor(-0.0201, dtype=torch.float64) | mean_values:  tensor(99.1782) | mean_reward:  tensor(0.9910, dtype=torch.float64)
# iteration =  195 : Actor loss =  0.019839082334238353 | Critic loss =  0.003321330703329295 | Total Loss =  0.02432822571676342 |
# mean_advantages:  tensor(-0.0004, dtype=torch.float64) | mean_values:  tensor(99.2008) | mean_reward:  tensor(0.9917, dtype=torch.float64)
# iteration =  196 : Actor loss =  -3.323703952441467e-05 | Critic loss =  0.004515006714500487 | Total Loss =  0.005080222988553992 |
# mean_advantages:  tensor(-0.0173, dtype=torch.float64) | mean_values:  tensor(99.2027) | mean_reward:  tensor(0.9912, dtype=torch.float64)
# iteration =  197 : Actor loss =  0.016791296529876352 | Critic loss =  0.003902973213698715 | Total Loss =  0.021614632783051858 |
# mean_advantages:  tensor(0.0134, dtype=torch.float64) | mean_values:  tensor(99.2036) | mean_reward:  tensor(0.9919, dtype=torch.float64)
# iteration =  198 : Actor loss =  -0.013587042969957592 | Critic loss =  0.002050841529853642 | Total Loss =  -0.009687301422309728 |
# mean_advantages:  tensor(-0.0444, dtype=torch.float64) | mean_values:  tensor(99.1948) | mean_reward:  tensor(0.9908, dtype=torch.float64)
# iteration =  199 : Actor loss =  0.04376358707340182 | Critic loss =  0.0041725553828291595 | Total Loss =  0.04877587704241955 |
# mean_advantages:  tensor(0.0337, dtype=torch.float64) | mean_values:  tensor(99.1628) | mean_reward:  tensor(0.9916, dtype=torch.float64)
# iteration =  200 : Actor loss =  -0.034139154310594194 | Critic loss =  0.00370189075358212 | Total Loss =  -0.02929141543970897 |
# mean_advantages:  tensor(-0.0268, dtype=torch.float64) | mean_values:  tensor(99.1760) | mean_reward:  tensor(0.9906, dtype=torch.float64)
# iteration =  201 : Actor loss =  0.026175461867470124 | Critic loss =  0.004375749707687646 | Total Loss =  0.03146363512693887 |
# mean_advantages:  tensor(0.0408, dtype=torch.float64) | mean_values:  tensor(99.2020) | mean_reward:  tensor(0.9923, dtype=torch.float64)
# iteration =  202 : Actor loss =  -0.04100467838808889 | Critic loss =  0.0033617428434081376 | Total Loss =  -0.03614539113706904 |
# mean_advantages:  tensor(0.0177, dtype=torch.float64) | mean_values:  tensor(99.2278) | mean_reward:  tensor(0.9921, dtype=torch.float64)
# iteration =  203 : Actor loss =  -0.017952954664190748 | Critic loss =  0.0034853987931273878 | Total Loss =  -0.012943434956080729 |
# mean_advantages:  tensor(0.0263, dtype=torch.float64) | mean_values:  tensor(99.2518) | mean_reward:  tensor(0.9927, dtype=torch.float64)
# iteration =  204 : Actor loss =  -0.026724745916533562 | Critic loss =  0.002120498394360766 | Total Loss =  -0.022305767929163108 |
# mean_advantages:  tensor(0.0140, dtype=torch.float64) | mean_values:  tensor(99.2769) | mean_reward:  tensor(0.9925, dtype=torch.float64)
# iteration =  205 : Actor loss =  -0.014289700542028504 | Critic loss =  0.0023705856408923866 | Total Loss =  -0.009676522758706917 |
# mean_advantages:  tensor(-0.0109, dtype=torch.float64) | mean_values:  tensor(99.2910) | mean_reward:  tensor(0.9923, dtype=torch.float64)
# iteration =  206 : Actor loss =  0.01031165682550175 | Critic loss =  0.0032764731463976204 | Total Loss =  0.015431805210678185 |
# mean_advantages:  tensor(0.0259, dtype=torch.float64) | mean_values:  tensor(99.2723) | mean_reward:  tensor(0.9929, dtype=torch.float64)
# iteration =  207 : Actor loss =  -0.026309613085668856 | Critic loss =  0.003045690134167671 | Total Loss =  -0.02128177943950551 |
# mean_advantages:  tensor(-0.0298, dtype=torch.float64) | mean_values:  tensor(99.3178) | mean_reward:  tensor(0.9924, dtype=torch.float64)
# iteration =  208 : Actor loss =  0.029487452739721313 | Critic loss =  0.003090433944016695 | Total Loss =  0.034586733346676606 |
# mean_advantages:  tensor(-0.0044, dtype=torch.float64) | mean_values:  tensor(99.2675) | mean_reward:  tensor(0.9924, dtype=torch.float64)
# iteration =  209 : Actor loss =  0.00408106440091595 | Critic loss =  0.0027703713066875935 | Total Loss =  0.009103312395700218 |
# mean_advantages:  tensor(0.0212, dtype=torch.float64) | mean_values:  tensor(99.2681) | mean_reward:  tensor(0.9926, dtype=torch.float64)
# iteration =  210 : Actor loss =  -0.02149608575390435 | Critic loss =  0.0015316343819722533 | Total Loss =  -0.01704318198958194 |
# mean_advantages:  tensor(0.0019, dtype=torch.float64) | mean_values:  tensor(99.2740) | mean_reward:  tensor(0.9925, dtype=torch.float64)
# iteration =  211 : Actor loss =  -0.002268277832000462 | Critic loss =  0.005476973764598369 | Total Loss =  0.00421809338343242 |
# mean_advantages:  tensor(0.0145, dtype=torch.float64) | mean_values:  tensor(99.2800) | mean_reward:  tensor(0.9928, dtype=torch.float64)
# iteration =  212 : Actor loss =  -0.014903548174825143 | Critic loss =  0.002698595749679953 | Total Loss =  -0.00971739170146978 |
# mean_advantages:  tensor(0.0061, dtype=torch.float64) | mean_values:  tensor(99.2750) | mean_reward:  tensor(0.9924, dtype=torch.float64)
# iteration =  213 : Actor loss =  -0.006389879621342072 | Critic loss =  0.002798073571175337 | Total Loss =  -0.0010528276439386094 |
# mean_advantages:  tensor(0.0314, dtype=torch.float64) | mean_values:  tensor(99.2751) | mean_reward:  tensor(0.9929, dtype=torch.float64)
# iteration =  214 : Actor loss =  -0.03180426726845671 | Critic loss =  0.002912632904481143 | Total Loss =  -0.02633537741290983 |
# mean_advantages:  tensor(0.0327, dtype=torch.float64) | mean_values:  tensor(99.3243) | mean_reward:  tensor(0.9936, dtype=torch.float64)
# iteration =  215 : Actor loss =  -0.0330302884032768 | Critic loss =  0.004355054469779134 | Total Loss =  -0.026701540376414055 |
# mean_advantages:  tensor(0.0272, dtype=torch.float64) | mean_values:  tensor(99.3545) | mean_reward:  tensor(0.9937, dtype=torch.float64)
# iteration =  216 : Actor loss =  -0.02742937178897796 | Critic loss =  0.0031936892215162515 | Total Loss =  -0.021566207083753626 |
# mean_advantages:  tensor(-0.0233, dtype=torch.float64) | mean_values:  tensor(99.3765) | mean_reward:  tensor(0.9933, dtype=torch.float64)
# iteration =  217 : Actor loss =  0.022931619106622014 | Critic loss =  0.002340002944692969 | Total Loss =  0.028445315730588106 |
# mean_advantages:  tensor(-0.0123, dtype=torch.float64) | mean_values:  tensor(99.3102) | mean_reward:  tensor(0.9926, dtype=torch.float64)
# iteration =  218 : Actor loss =  0.011610795454182216 | Critic loss =  0.002734454362653196 | Total Loss =  0.01726451103721235 |
# mean_advantages:  tensor(0.0149, dtype=torch.float64) | mean_values:  tensor(99.3596) | mean_reward:  tensor(0.9934, dtype=torch.float64)
# iteration =  219 : Actor loss =  -0.01508987530518165 | Critic loss =  0.0018333843490108848 | Total Loss =  -0.009983748846331894 |
# mean_advantages:  tensor(0.0216, dtype=torch.float64) | mean_values:  tensor(99.3363) | mean_reward:  tensor(0.9933, dtype=torch.float64)
# iteration =  220 : Actor loss =  -0.02199475227405314 | Critic loss =  0.0027908070478588343 | Total Loss =  -0.016343544959248946 |
# mean_advantages:  tensor(-0.0160, dtype=torch.float64) | mean_values:  tensor(99.3389) | mean_reward:  tensor(0.9927, dtype=torch.float64)
# iteration =  221 : Actor loss =  0.015726937322250813 | Critic loss =  0.0019285626907367258 | Total Loss =  0.020948356037915002 |
# mean_advantages:  tensor(-0.0204, dtype=torch.float64) | mean_values:  tensor(99.3629) | mean_reward:  tensor(0.9927, dtype=torch.float64)
# iteration =  222 : Actor loss =  0.01999240524708043 | Critic loss =  0.0021963197423610836 | Total Loss =  0.025258899274535774 |
# mean_advantages:  tensor(-0.0107, dtype=torch.float64) | mean_values:  tensor(99.3579) | mean_reward:  tensor(0.9931, dtype=torch.float64)
# iteration =  223 : Actor loss =  0.010242757030695644 | Critic loss =  0.002133447624510154 | Total Loss =  0.01544580499995776 |
# mean_advantages:  tensor(-0.0041, dtype=torch.float64) | mean_values:  tensor(99.3794) | mean_reward:  tensor(0.9934, dtype=torch.float64)
# iteration =  224 : Actor loss =  0.0039050502362255306 | Critic loss =  0.0020906197535805406 | Total Loss =  0.009047079325845865 |
# mean_advantages:  tensor(0.0037, dtype=torch.float64) | mean_values:  tensor(99.3620) | mean_reward:  tensor(0.9932, dtype=torch.float64)
# iteration =  225 : Actor loss =  -0.00403431133170238 | Critic loss =  0.0022877093218266966 | Total Loss =  0.0012380237291697575 |
# mean_advantages:  tensor(0.0329, dtype=torch.float64) | mean_values:  tensor(99.3562) | mean_reward:  tensor(0.9937, dtype=torch.float64)
# iteration =  226 : Actor loss =  -0.033157097705416055 | Critic loss =  0.0028192134527489543 | Total Loss =  -0.027529245727937347 |
# mean_advantages:  tensor(-0.0173, dtype=torch.float64) | mean_values:  tensor(99.3854) | mean_reward:  tensor(0.9934, dtype=torch.float64)
# iteration =  227 : Actor loss =  0.016771864654248066 | Critic loss =  0.002924385480582714 | Total Loss =  0.0224311913277334 |
# mean_advantages:  tensor(0.0005, dtype=torch.float64) | mean_values:  tensor(99.3779) | mean_reward:  tensor(0.9934, dtype=torch.float64)
# iteration =  228 : Actor loss =  -0.0006503611685596692 | Critic loss =  0.0013087180478032678 | Total Loss =  0.004029200286126668 |
# mean_advantages:  tensor(-0.1136, dtype=torch.float64) | mean_values:  tensor(99.3071) | mean_reward:  tensor(0.9917, dtype=torch.float64)
# iteration =  229 : Actor loss =  0.11144434398805156 | Critic loss =  0.037480616755783555 | Total Loss =  0.13396484258651167 |
# mean_advantages:  tensor(0.0136, dtype=torch.float64) | mean_values:  tensor(99.3036) | mean_reward:  tensor(0.9928, dtype=torch.float64)
# iteration =  230 : Actor loss =  -0.01399187332095502 | Critic loss =  0.002396238602232188 | Total Loss =  -0.009167434773006643 |
# mean_advantages:  tensor(0.0119, dtype=torch.float64) | mean_values:  tensor(99.3231) | mean_reward:  tensor(0.9928, dtype=torch.float64)
# iteration =  231 : Actor loss =  -0.012168277952020303 | Critic loss =  0.0023465352831408383 | Total Loss =  -0.007315194181298156 |
# mean_advantages:  tensor(0.0099, dtype=torch.float64) | mean_values:  tensor(99.3103) | mean_reward:  tensor(0.9926, dtype=torch.float64)
# iteration =  232 : Actor loss =  -0.010208609725410695 | Critic loss =  0.003179426861461252 | Total Loss =  -0.004885334110182357 |
# mean_advantages:  tensor(-0.0291, dtype=torch.float64) | mean_values:  tensor(99.3076) | mean_reward:  tensor(0.9926, dtype=torch.float64)
# iteration =  233 : Actor loss =  0.028484968028686643 | Critic loss =  0.004152394712436944 | Total Loss =  0.03430304524856962 |
# mean_advantages:  tensor(-0.0226, dtype=torch.float64) | mean_values:  tensor(99.2895) | mean_reward:  tensor(0.9922, dtype=torch.float64)
# iteration =  234 : Actor loss =  0.02222622519299912 | Critic loss =  0.002898700521327555 | Total Loss =  0.027367996612438585 |
# mean_advantages:  tensor(-0.0492, dtype=torch.float64) | mean_values:  tensor(99.2340) | mean_reward:  tensor(0.9916, dtype=torch.float64)
# iteration =  235 : Actor loss =  0.047970781220304605 | Critic loss =  0.011222102828323841 | Total Loss =  0.05722312632826606 |
# mean_advantages:  tensor(0.0004, dtype=torch.float64) | mean_values:  tensor(99.2529) | mean_reward:  tensor(0.9923, dtype=torch.float64)
# iteration =  236 : Actor loss =  -0.0007087837186451254 | Critic loss =  0.0025907895620912312 | Total Loss =  0.004156428011712134 |
# mean_advantages:  tensor(0.0040, dtype=torch.float64) | mean_values:  tensor(99.2614) | mean_reward:  tensor(0.9925, dtype=torch.float64)
# iteration =  237 : Actor loss =  -0.004500063867720871 | Critic loss =  0.005378670920617878 | Total Loss =  0.0017999842595838925 |
# mean_advantages:  tensor(0.0128, dtype=torch.float64) | mean_values:  tensor(99.2290) | mean_reward:  tensor(0.9918, dtype=torch.float64)
# iteration =  238 : Actor loss =  -0.013074609426435265 | Critic loss =  0.0025705884350463747 | Total Loss =  -0.008140088653776974 |
# mean_advantages:  tensor(0.0194, dtype=torch.float64) | mean_values:  tensor(99.3008) | mean_reward:  tensor(0.9932, dtype=torch.float64)
# iteration =  239 : Actor loss =  -0.019649917051073554 | Critic loss =  0.00200010450091213 | Total Loss =  -0.015004777855582924 |
# mean_advantages:  tensor(-0.0092, dtype=torch.float64) | mean_values:  tensor(99.3049) | mean_reward:  tensor(0.9925, dtype=torch.float64)
# iteration =  240 : Actor loss =  0.009062267610966013 | Critic loss =  0.0018604779825545847 | Total Loss =  0.013659299633395641 |
# mean_advantages:  tensor(-0.0095, dtype=torch.float64) | mean_values:  tensor(99.3065) | mean_reward:  tensor(0.9927, dtype=torch.float64)
# iteration =  241 : Actor loss =  0.009291332833094154 | Critic loss =  0.0021212216676212846 | Total Loss =  0.014018207676566773 |
# mean_advantages:  tensor(-0.0261, dtype=torch.float64) | mean_values:  tensor(99.2717) | mean_reward:  tensor(0.9921, dtype=torch.float64)
# iteration =  242 : Actor loss =  0.025902536914363842 | Critic loss =  0.0025617440836504103 | Total Loss =  0.03081421851660718 |
# mean_advantages:  tensor(0.0306, dtype=torch.float64) | mean_values:  tensor(99.2624) | mean_reward:  tensor(0.9927, dtype=torch.float64)
# iteration =  243 : Actor loss =  -0.031009841977402842 | Critic loss =  0.0025686961435712873 | Total Loss =  -0.026071824918518116 |
# mean_advantages:  tensor(0.0161, dtype=torch.float64) | mean_values:  tensor(99.2976) | mean_reward:  tensor(0.9930, dtype=torch.float64)
# iteration =  244 : Actor loss =  -0.01616716670348411 | Critic loss =  0.001814384841127321 | Total Loss =  -0.011504837561618625 |
# mean_advantages:  tensor(-0.0019, dtype=torch.float64) | mean_values:  tensor(99.3006) | mean_reward:  tensor(0.9924, dtype=torch.float64)
# iteration =  245 : Actor loss =  0.0015787653666442642 | Critic loss =  0.0025223000440746544 | Total Loss =  0.00662034755754158 |
# mean_advantages:  tensor(0.0326, dtype=torch.float64) | mean_values:  tensor(99.3119) | mean_reward:  tensor(0.9934, dtype=torch.float64)
# iteration =  246 : Actor loss =  -0.032854061636160115 | Critic loss =  0.0029973835637792947 | Total Loss =  -0.027541187041922464 |
# mean_advantages:  tensor(0.0074, dtype=torch.float64) | mean_values:  tensor(99.3259) | mean_reward:  tensor(0.9929, dtype=torch.float64)
# iteration =  247 : Actor loss =  -0.007583718471286954 | Critic loss =  0.0027263140375725927 | Total Loss =  -0.0023141739194394496 |
# mean_advantages:  tensor(-0.0010, dtype=torch.float64) | mean_values:  tensor(99.3260) | mean_reward:  tensor(0.9924, dtype=torch.float64)
# iteration =  248 : Actor loss =  0.0007010328415639319 | Critic loss =  0.003304732469841838 | Total Loss =  0.006367168046519867 |
# mean_advantages:  tensor(0.0874, dtype=torch.float64) | mean_values:  tensor(99.4188) | mean_reward:  tensor(0.9841, dtype=torch.float64)
# iteration =  249 : Actor loss =  -0.0924552520249237 | Critic loss =  0.14710025772452354 | Total Loss =  -0.014545294095409354 |

# %%
agent.saved()

# %%
env_name = "cartpole-balance"
env = make_dmc_env(env_name, np.random.randint(0, 1000000), flatten=True, use_pixels=False)
agent.test(load = True, vedio=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# ...
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# C:\Users\User\AppData\Local\Temp\ipykernel_10100\1936748799.py:155: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mean, std = self.policy_net(torch.as_tensor(np.array(torch.as_tensor(state), dtype=np.float32)))
# 993.5593758751615
# c:\Users\User\anaconda3\envs\DRL\lib\site-packages\imageio\plugins\pillow.py:409: DeprecationWarning: The keyword `fps` is no longer supported. Use `duration`(in ms) instead, e.g. `fps=50` == `duration=20` (1000 * 1/50).
#   warnings.warn(
